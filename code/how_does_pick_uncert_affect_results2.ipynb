# %%
import pandas as pd
import setup_paths as paths
import matplotlib.pyplot as plt
import numpy as np
import data_plotting_func_min_dist as data_plotting
import matplotlib
import numpy.ma as ma

# %%
filenames = ['eq_object_04s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
             'eq_object_41s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
			 'eq_object_06s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
			 'eq_object_11s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
             'eq_object_1s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
		 	 'eq_object_03s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
			 'eq_object_1s_snr_20_blank_01_reviews_snr_20_delay.pkl',
             'eq_object_03s_snr_20_blank_01_reviews_snr_20_delay.pkl',
	 		 'eq_object_4s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
			 'eq_object_05s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl',
			 'eq_object_4s_snr_20_blank_01_reviews_snr_20_delay.pkl',
			 'eq_object_05s_snr_20_blank_01_reviews_snr_20_delay.pkl']

# %%
paths.data_path
# Out:
# '/home/earthquakes1/homes/Rebecca/phd/seismo_det/code/../../data/'

# %%
filenames = ['eq_object_04s_snr_20_blank_01_reviews_snr_20_delay.pkl',
		 	 'eq_object_02s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl']

min_dist = 0
max_dist = 200

f = filenames[0]
df_04_01 = pd.read_pickle(paths.data_path + '/results_database_different_window_lengths_for_reviews_delay/results_' + f + '.pkl')
f = filenames[1]
df_02_neg_01 = pd.read_pickle(paths.data_path + '/results_database_different_window_lengths_for_reviews_delay/results_' + f + '.pkl')

df_03 = pd.read_pickle('/home/earthquakes1/homes/Rebecca/phd/data/results_database_combined_azimuths_reviews/results_eq_object_03s_snr_20_blank_0_reviews_snr_20.pkl.pkl')
df_05 = pd.read_pickle('/home/earthquakes1/homes/Rebecca/phd/data/results_database_combined_azimuths_reviews/results_eq_object_05s_snr_20_blank_0_reviews_snr_20.pkl.pkl')
df_1 = pd.read_pickle('/home/earthquakes1/homes/Rebecca/phd/data/results_database_combined_azimuths_reviews/results_eq_object_1s_snr_20_blank_0_reviews_snr_20.pkl.pkl')
df_4 = pd.read_pickle('/home/earthquakes1/homes/Rebecca/phd/data/results_database_combined_azimuths_reviews/results_eq_object_4s_snr_20_blank_0_reviews_snr_20.pkl.pkl')

# %%
df_02_neg_01[df_02_neg_01['eq_id']=='1947713']
# Out:
#    level_0  index    eq_id  eq_mag eq_mag_type          eq_time  \
# 4        4      0  1947713     5.0          MW  20050204_091538
#
#                       eq_loc  \
# 4  (-37.922, -73.3985, 22.8)
#
#                                               tp_max  \
# 4  [0.4988821594228001, 0.40940317990063774, 0.42...
#
#                                      tp_max_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                   tc  \
# 4  [0.3123084806458312, 0.28817168052667586, 0.60...
#
#                                          tc_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                  iv2  \
# 4  [4.584584149412492e-12, 9.430629547238114e-08,...
#
#                                        iv2_distances  \
# 4  [46.52436835522224 km, 45.99021789372439 km, 3...
#
#                                         iv2_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                  pgd  \
# 4  [4.293562895269085e-07, 4.859628472094973e-05,...
#
#                                        pgd_distances  \
# 4  [46.52436835522224 km, 45.99021789372439 km, 3...
#
#                                         pgd_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A406., ZW.A4...
#
#                                        distance_dict  \
# 4  {'ZW.A401.': 51.769043605734154, 'ZW.A402.': 5...
#
#                                         azimuth_dict
# 4  {'ZW.A401.': 175.7254064462551, 'ZW.A402.': -1...

# %%
df_03[df_03['eq_id']=='1947713']
# Out:
#    level_0  index    eq_id  eq_mag eq_mag_type          eq_time  \
# 4        4      0  1947713     5.0          MW  20050204_091538
#
#                       eq_loc  \
# 4  (-37.922, -73.3985, 22.8)
#
#                                               tp_max  \
# 4  [0.4191753547986052, 0.40940317990063774, 0.27...
#
#                                      tp_max_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                   tc  \
# 4  [0.29907925737335306, 0.24328713385763964, 0.2...
#
#                                          tc_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                  iv2  \
# 4  [1.3827673572449637e-10, 1.694572163690084e-07...
#
#                                        iv2_distances  \
# 4  [46.52436835522224 km, 45.99021789372439 km, 3...
#
#                                         iv2_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                  pgd  \
# 4  [2.9844854382289758e-06, 4.859628472094973e-05...
#
#                                        pgd_distances  \
# 4  [46.52436835522224 km, 45.99021789372439 km, 3...
#
#                                         pgd_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A406., ZW.A4...
#
#                                        distance_dict  \
# 4  {'ZW.A401.': 51.769043605734154, 'ZW.A402.': 5...
#
#                                         azimuth_dict
# 4  {'ZW.A401.': 175.7254064462551, 'ZW.A402.': -1...

# %%
df_04_01[df_04_01['eq_id']=='1947713']
# Out:
#    level_0  index    eq_id  eq_mag eq_mag_type          eq_time  \
# 4        4      0  1947713     5.0          MW  20050204_091538
#
#                       eq_loc  \
# 4  (-37.922, -73.3985, 22.8)
#
#                                               tp_max  \
# 4  [0.3637637309535454, 0.30947623209675507, 0.24...
#
#                                      tp_max_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                   tc  \
# 4  [0.4886743837534872, 0.24558623100073626, 0.25...
#
#                                          tc_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                  iv2  \
# 4  [2.1006395211162764e-10, 3.5339611820572935e-0...
#
#                                        iv2_distances  \
# 4  [46.52436835522224 km, 45.99021789372439 km, 3...
#
#                                         iv2_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
#
#                                                  pgd  \
# 4  [3.710399506895767e-06, 8.9538606473997e-05, 3...
#
#                                        pgd_distances  \
# 4  [46.52436835522224 km, 45.99021789372439 km, 3...
#
#                                         pgd_stations  \
# 4  [ZW.A401., ZW.A402., ZW.A403., ZW.A406., ZW.A4...
#
#                                        distance_dict  \
# 4  {'ZW.A401.': 51.769043605734154, 'ZW.A402.': 5...
#
#                                         azimuth_dict
# 4  {'ZW.A401.': 175.7254064462551, 'ZW.A402.': -1...

# %%
compare_true_shifted = pd.merge(df_03, df_04_01, on='eq_id', suffixes=('_03', '_04_01'))

# %%
compare_true_shifted.rename(columns={'eq_mag_true': 'eq_mag'}, inplace=True)

# %%
options = {'n': 1, 'min_dist': 0, 'max_dist': 200}
x_tp_04_01, y_tp_04_01 = data_plotting.calc_tp_mag_lim(df_04_01, 3., **options)
x_tp_03, y_tp_03 = data_plotting.calc_tp_mag_lim(df_03, 3., **options)
x_tp_02_neg_01, y_tp_02_neg_01 = data_plotting.calc_tp_mag_lim(df_02_neg_01, 3., **options)
x_tp_02_neg_01 = np.array(x_tp_02_neg_01)
y_tp_02_neg_01 = np.array(y_tp_02_neg_01)
x_tp_04_01 = np.array(x_tp_04_01)
y_tp_04_01 = np.array(y_tp_04_01)
x_tp_03 = np.array(x_tp_03)
y_tp_03 = np.array(y_tp_03)

# %%
x_tc_04_01, y_tc_04_01 = data_plotting.calc_tc_mag_lim(df_04_01, 3., **options)
x_tc_03, y_tc_03 = data_plotting.calc_tc_mag_lim(df_03, 3., **options)
x_tc_02_neg_01, y_tc_02_neg_01 = data_plotting.calc_tc_mag_lim(df_02_neg_01, 3., **options)
x_tc_02_neg_01 = np.array(x_tc_02_neg_01)
y_tc_02_neg_01 = np.array(y_tc_02_neg_01)
x_tc_04_01 = np.array(x_tc_04_01)
y_tc_04_01 = np.array(y_tc_04_01)
x_tc_03 = np.array(x_tc_03)
y_tc_03 = np.array(y_tc_03)

# %%
x_iv2_04_01, y_iv2_04_01 = data_plotting.calc_iv2_mag_lim(df_04_01, 3., **options)
x_iv2_03, y_iv2_03 = data_plotting.calc_iv2_mag_lim(df_03, 3., **options)
x_iv2_02_neg_01, y_iv2_02_neg_01 = data_plotting.calc_iv2_mag_lim(df_02_neg_01, 3., **options)
x_iv2_02_neg_01 = np.array(x_iv2_02_neg_01)
y_iv2_02_neg_01 = np.array(y_iv2_02_neg_01)
x_iv2_04_01 = np.array(x_iv2_04_01)
y_iv2_04_01 = np.array(y_iv2_04_01)
x_iv2_03 = np.array(x_iv2_03)
y_iv2_03 = np.array(y_iv2_03)

# %%
x_pgd_04_01, y_pgd_04_01 = data_plotting.calc_pgd_mag_lim(df_04_01, 3., **options)
x_pgd_03, y_pgd_03 = data_plotting.calc_pgd_mag_lim(df_03, 3., **options)
x_pgd_02_neg_01, y_pgd_02_neg_01 = data_plotting.calc_pgd_mag_lim(df_02_neg_01, 3., **options)
x_pgd_02_neg_01 = np.array(x_pgd_02_neg_01)
y_pgd_02_neg_01 = np.array(y_pgd_02_neg_01)
x_pgd_04_01 = np.array(x_pgd_04_01)
y_pgd_04_01 = np.array(y_pgd_04_01)
x_pgd_03 = np.array(x_pgd_03)
y_pgd_03 = np.array(y_pgd_03)

# %%
plt.scatter(x_tp_04_01, y_tp_04_01-y_tp_03)

# %%
plt.scatter(x_tc_04_01, y_tc_04_01-y_tc_03)

# %%
y_iv2_03
# Out:
# array([-5.40891628, -6.52388991, -3.445609  , ..., -7.07404073,
#        -8.53942788, -5.6738811 ])

# %%
row['iv2_03']
# Out:
# [None,
#  None,
#  -5.706000190828054e-11,
#  2.6464990175950932e-09,
#  1.0166809502694881e-07]

# %%
masked
# Out:
# masked_array(data=[None, None, -5.706000190828054e-11,
#                    2.6464990175950932e-09, 1.0166809502694881e-07],
#              mask=False,
#        fill_value='?',
#             dtype=object)

# %%
np.where(row['iv2_03']==None)
# Out:
# /tmp/ipykernel_1657073/4161348988.py:1: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   np.where(row['iv2_03']==None)
# (array([], dtype=int64),)

# %%
x_iv2_04_01 = []
x_iv2_03 = []
y_iv2_04_01 = []
y_iv2_03 = []
for i, row in compare_true_shifted.iterrows():
	#print(row['iv2_03'], row['iv2_04_01'], row['eq_mag_03'], row['eq_mag_04_01'])
	x_iv2_04_01.append(row['eq_mag_04_01'])
	use = []
	for iv2 in row['iv2_04_01']:
		if iv2 is not None:
			use.append(iv2)
	y_iv2_04_01.append(np.median(use))
	x_iv2_03.append(row['eq_mag_03'])
	use = []
	for iv2 in row['iv2_03']:
		if iv2 is not None:
			use.append(iv2)
	y_iv2_03.append(np.median(use))
	#print(y_iv2_03, y_iv2_04_01)

y_iv2_03 = np.array(y_iv2_03)
y_iv2_04_01 = np.array(y_iv2_04_01)
x_iv2_03 = np.array(x_iv2_03)
x_iv2_04_01 = np.array(x_iv2_04_01)
# Out:
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
df_4
# Out:
#       level_0  index     eq_id  eq_mag eq_mag_type          eq_time  \
# 0           0      0   2110129    5.00          MW  20050131_173151
# 1           1      0   2011699    5.30          MW  20050120_185630
# 2           2      0   2000953    5.00          MW  20050118_092558
# 3           3      0   2000808    5.20          MW  20050118_083600
# 4           4      0   1947713    5.00          MW  20050204_091538
# ...       ...    ...       ...     ...         ...              ...
# 4432     2318      0  11140120    4.10          mb  20191101_234328
# 4433     2319      0  11139880    5.30         Mww  20191101_152412
# 4434     2320      0  11139830    3.55          Mw  20191101_093317
# 4435     2321      0  11139801    3.20          ML  20191101_070002
# 4436     2322      0  11139785    4.70         Mww  20191101_052545
#
#                             eq_loc  \
# 0        (-41.6009, 175.838, 19.9)
# 1       (-41.1222, 174.9773, 39.7)
# 2       (-41.5413, 175.8527, 21.0)
# 3        (-41.6055, 175.8911, 9.2)
# 4        (-37.922, -73.3985, 22.8)
# ...                            ...
# 4432   (-29.1792, -71.8827, 37.04)
# 4433    (11.5712, -86.7909, 50.02)
# 4434  (36.568833, -117.976, 10.79)
# 4435      (39.137, -119.6248, 8.2)
# 4436     (40.5178, 20.8117, 13.69)
#
#                                                  tp_max  \
# 0                                  [0.4606962267009133]
# 1                                 [0.42668707984997223]
# 2                                   [1.751189476872014]
# 3              [1.5581815100077676, 1.1656885463505522]
# 4     [0.4191753547986052, 0.40940317990063774, 0.27...
# ...                                                 ...
# 4432           [2.122365396005637, 0.24676753807402385]
# 4433  [1.5794086189218965, 0.9599298495581294, 1.528...
# 4434  [0.7219045391356451, 0.222702389051299, 0.3741...
# 4435           [0.17066622598607115, 2.043719412573478]
# 4436  [1.1360883225259564, 1.1909240545782556, 0.351...
#
#                                         tp_max_stations  \
# 0                                           [NZ.MRZ.10]
# 1                                           [NZ.MRZ.10]
# 2                                           [NZ.MRZ.10]
# 3                                [NZ.BFZ.10, NZ.MRZ.10]
# 4     [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
# ...                                                 ...
# 4432                               [C1.AC04., C1.CO10.]
# 4433           [NU.CNGN., NU.CRIN., NU.HERN., NU.NANN.]
# 4434  [CI.CGO., CI.CWC., NN.DSP., CI.FUR., CI.GRA., ...
# 4435                                 [NN.PNT., NN.WAK.]
# 4436  [HT.IGT., HL.JAN., AC.KBN., HL.KZN., HT.NEST.,...
#
#                                                      tc  \
# 0                                  [1.0022111770881148]
# 1                                 [0.43499592090170686]
# 2                                  [1.1421424496676096]
# 3               [1.5770696642378434, 1.065111961357058]
# 4     [0.4015376825757337, 0.20404516427349798, 0.47...
# ...                                                 ...
# 4432         [0.34765050366468947, 0.27888436707797537]
# 4433  [1.307079494316718, 0.7563192348928099, 1.2776...
# 4434  [0.21393382288347187, 0.12604295919905, 0.2544...
# 4435           [0.3184121872812793, 0.3456258437731603]
# 4436  [0.7059499153012642, 0.5963150660344217, 1.439...
#
#                                             tc_stations  \
# 0                                           [NZ.MRZ.10]
# 1                                           [NZ.MRZ.10]
# 2                                           [NZ.MRZ.10]
# 3                                [NZ.BFZ.10, NZ.MRZ.10]
# 4     [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
# ...                                                 ...
# 4432                               [C1.AC04., C1.CO10.]
# 4433           [NU.CNGN., NU.CRIN., NU.HERN., NU.NANN.]
# 4434  [CI.CGO., CI.CWC., NN.DSP., CI.FUR., CI.GRA., ...
# 4435                                 [NN.PNT., NN.WAK.]
# 4436  [HT.IGT., HL.JAN., AC.KBN., HL.KZN., HT.NEST.,...
#
#                                                     iv2  \
# 0                                                    []
# 1                                [5.25845566390678e-07]
# 2                                                    []
# 3                                                    []
# 4     [4.08152446824354e-09, 8.110987145115999e-06, ...
# ...                                                 ...
# 4432                           [3.6437146925455226e-08]
# 4433                            [5.784933536467088e-06]
# 4434  [5.831978589925278e-07, 9.987629609598482e-08,...
# 4435   [2.4878486587074865e-07, 1.7638294796299046e-11]
# 4436  [3.900665621358676e-09, 1.5125002654516644e-06...
#
#                                           iv2_distances  \
# 0                                                    []
# 1                                [72.07969998851411 km]
# 2                                                    []
# 3                                                    []
# 4     [46.52436835522224 km, 45.99021789372439 km, 3...
# ...                                                 ...
# 4432                             [41.57949818031772 km]
# 4433                             [83.56438721336707 km]
# 4434  [15.62630164052065 km, 17.177205341114774 km, ...
# 4435       [5.743782441809731 km, 72.08248024187326 km]
# 4436  [95.72545937963437 km, 11.927475379973764 km, ...
#
#                                            iv2_stations  \
# 0                                                    []
# 1                                           [NZ.MRZ.10]
# 2                                                    []
# 3                                                    []
# 4     [ZW.A401., ZW.A402., ZW.A403., ZW.A404., ZW.A4...
# ...                                                 ...
# 4432                                         [C1.CO10.]
# 4433                                         [NU.NANN.]
# 4434  [CI.CGO., CI.CWC., NN.DSP., CI.GRA., CI.JRC2.,...
# 4435                                 [NN.PNT., NN.WAK.]
# 4436    [HL.JAN., AC.KBN., HL.KZN., HT.NEST., HL.PENT.]
#
#                                                     pgd  \
# 0                                [2.31124697292753e-05]
# 1                               [7.076419000669949e-05]
# 2                              [1.1986653920724827e-05]
# 3      [1.2883965377921061e-05, 1.5463955071934124e-05]
# 4     [4.862866841784501e-06, 0.00011545285447399174...
# ...                                                 ...
# 4432    [9.053597050514735e-07, 2.5869818508969935e-05]
# 4433      [6.185547856482595e-05, 0.000534714532439829]
# 4434  [5.693933928736603e-05, 1.1126874039563892e-05...
# 4435    [3.0381959013280602e-05, 4.436633034645339e-07]
# 4436  [1.4644247211819292e-05, 8.452550359625936e-06...
#
#                                           pgd_distances  \
# 0                               [106.68083076278864 km]
# 1                                [72.07969998851411 km]
# 2                                [100.4879719628321 km]
# 3         [107.05746146962363 km, 108.1752118389166 km]
# 4     [46.52436835522224 km, 45.99021789372439 km, 3...
# ...                                                 ...
# 4432       [133.8459329456974 km, 41.57949818031772 km]
# 4433       [128.0167604106423 km, 83.56438721336707 km]
# 4434  [15.62630164052065 km, 17.177205341114774 km, ...
# 4435       [5.743782441809731 km, 72.08248024187326 km]
# 4436  [116.98151888241351 km, 95.72545937963437 km, ...
#
#                                            pgd_stations  \
# 0                                           [NZ.MRZ.10]
# 1                                           [NZ.MRZ.10]
# 2                                           [NZ.MRZ.10]
# 3                                [NZ.BFZ.10, NZ.MRZ.10]
# 4     [ZW.A401., ZW.A402., ZW.A403., ZW.A406., ZW.A4...
# ...                                                 ...
# 4432                               [C1.AC04., C1.CO10.]
# 4433                               [NU.CRIN., NU.NANN.]
# 4434  [CI.CGO., CI.CWC., NN.DSP., CI.FUR., CI.GRA., ...
# 4435                                 [NN.PNT., NN.WAK.]
# 4436     [HT.IGT., HL.JAN., AC.KBN., HL.KZN., HT.NEST.]
#
#                                           distance_dict  \
# 0     {'IU.SNZO.00': 102.08314562572458, 'NZ.BFZ.10'...
# 1     {'IU.SNZO.00': 50.273212837431664, 'NZ.MRZ.10'...
# 2     {'IU.SNZO.00': 101.6008496163856, 'NZ.BFZ.10':...
# 3     {'IU.SNZO.00': 104.89522924441958, 'NZ.BFZ.10'...
# 4     {'ZW.A401.': 51.769043605734154, 'ZW.A402.': 5...
# ...                                                 ...
# 4432  {'C.GO04.': 156.03739863217808, 'C1.AC04.': 13...
# 4433  {'NU.CARN.00': 153.21529323404573, 'NU.CNGN.':...
# 4434  {'BK.KARE.00': 137.184039278157, 'BK.KCC.00': ...
# 4435  {'BK.BUCR.00': 168.97043758903155, 'BK.CMB.00'...
# 4436  {'AC.KBN.': 17.561798567910984, 'AC.VLO.': 112...
#
#                                            azimuth_dict
# 0     {'IU.SNZO.00': -71.39814996005346, 'NZ.BFZ.10'...
# 1     {'IU.SNZO.00': -132.33427803852754, 'NZ.MRZ.10...
# 2     {'IU.SNZO.00': -75.26438587458226, 'NZ.BFZ.10'...
# 3     {'IU.SNZO.00': -71.94018844036243, 'NZ.BFZ.10'...
# 4     {'ZW.A401.': 175.7254064462551, 'ZW.A402.': -1...
# ...                                                 ...
# 4432  {'C.GO04.': 136.81241760481643, 'C1.AC04.': 36...
# 4433  {'NU.CARN.00': 107.03038511884024, 'NU.CNGN.':...
# 4434  {'BK.KARE.00': -88.21273739687454, 'BK.KCC.00'...
# 4435  {'BK.BUCR.00': -164.14279868132093, 'BK.CMB.00...
# 4436  {'AC.KBN.': -9.888988261499124, 'AC.VLO.': -92...
#
# [4437 rows x 19 columns]

# %%
x_iv2_4 = []
y_iv2_4 = []
for i, row in df_4.iterrows():
	use = []
	for iv2 in row['iv2']:
		if iv2 is not None:
			use.append(iv2)
	y_iv2_4.append(np.median(use))
	x_iv2_4.append(row['eq_mag'])

y_iv2_4 = np.array(y_iv2_4)
x_iv2_4 = np.array(x_iv2_4)
# Out:
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
x_pgd_05 = []
y_pgd_05 = []
for i, row in df_05.iterrows():
	use = []
	for pgd in row['pgd']:
		if pgd is not None:
			use.append(pgd)
	y_pgd_05.append(np.median(use))
	x_pgd_05.append(row['eq_mag'])

y_pgd_05 = np.array(y_pgd_05)
x_pgd_05 = np.array(x_pgd_05)
# Out:
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
x_pgd_1 = []
y_pgd_1 = []
for i, row in df_1.iterrows():
	use = []
	for pgd in row['pgd']:
		if pgd is not None:
			use.append(pgd)
	y_pgd_1.append(np.median(use))
	x_pgd_1.append(row['eq_mag'])

y_pgd_1 = np.array(y_pgd_1)
x_pgd_1 = np.array(x_pgd_1)

# %%
x_pgd_4 = []
y_pgd_4 = []
for i, row in df_4.iterrows():
	use = []
	for pgd in row['pgd']:
		if pgd is not None:
			use.append(pgd)
	y_pgd_4.append(np.median(use))
	x_pgd_4.append(row['eq_mag'])

y_pgd_4 = np.array(y_pgd_4)
x_pgd_4 = np.array(x_pgd_4)
# Out:
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
y_iv2_04_01
# Out:
# array([           nan, 1.27521793e-09,            nan, ...,
#        5.22007126e-09, 7.21418399e-08, 3.66883608e-10])

# %%
y_iv2_03
# Out:
# array([           nan, 7.50685063e-10,            nan, ...,
#        4.13282561e-09, 7.39517758e-08, 2.18082714e-10])

# %%
plt.scatter(x_iv2_04_01, y_iv2_04_01-y_iv2_03)
plt.yscale('log')

# %%
x_pgd_04_01 = []
x_pgd_03 = []
y_pgd_04_01 = []
y_pgd_03 = []
for i, row in compare_true_shifted.iterrows():
	#print(row['pgd_03'], row['pgd_04_01'], row['eq_mag_03'], row['eq_mag_04_01'])
	x_pgd_04_01.append(row['eq_mag_04_01'])
	use = []
	for pgd in row['pgd_04_01']:
		if pgd is not None:
			use.append(pgd)
	y_pgd_04_01.append(np.median(use))
	x_pgd_03.append(row['eq_mag_03'])
	use = []
	for pgd in row['pgd_03']:
		if pgd is not None:
			use.append(pgd)
	y_pgd_03.append(np.median(use))
	#print(y_pgd_03, y_pgd_04_01)

y_pgd_03 = np.array(y_pgd_03)
y_pgd_04_01 = np.array(y_pgd_04_01)
x_pgd_03 = np.array(x_pgd_03)
x_pgd_04_01 = np.array(x_pgd_04_01)
# Out:
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/earthquakes1/software/Ubuntu/anaconda3/envs/rlc6/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.scatter(x_pgd_04_01, y_pgd_04_01-y_pgd_03)
plt.yscale('log')

# %%
# import os
# import glob

# # Set the root directory you want to search from
# root_dir = "."

# # Pattern to match the specific files
# #pattern = "eq_object_06s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl"
# list_of_patterns = ["eq_object_06s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl",
#                    "eq_object_11s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl",
#                    "eq_object_41s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl",
#                    "eq_object_04s_snr_20_blank_neg_01_reviews_snr_20_delay.pkl"]
# for pattern in list_of_patterns:
#     # Recursively find all matching files
#     for filepath in glob.iglob(f"{root_dir}/**/{pattern}", recursive=True):
#         # Create the new filename
#         new_filename = filepath.replace("blank_neg_01", "blank_01")
        
#         # Rename the file
#         os.rename(filepath, new_filename)
#         print(f"Renamed: {filepath} -> {new_filename}")

# %%
y_iv2_03
# Out:
# array([-5.40891628, -6.52388991, -3.445609  , ..., -7.07404073,
#        -8.53942788, -5.6738811 ])

# %%
plt.scatter(x_iv2_03, y_iv2_03)
plt.ylim(10**-14, 10**-5)
plt.yscale('log')

# %%
y_iv2_03
# Out:
# array([           nan, 7.50685063e-10,            nan, ...,
#        7.15554346e-11, 7.39517758e-08, 1.14705359e-11])

# %%
plt.scatter(x_iv2_4, y_iv2_4)
plt.yscale('log')

# %%
plt.scatter(x_pgd_4, y_pgd_4)
plt.yscale('log')

# %%
y_pgd_03
# Out:
# array([1.34516281e-06, 6.90821833e-06, 1.44636768e-06, ...,
#        1.14739318e-06, 1.54128112e-05, 1.49991517e-06])

# %%
plt.scatter(x_pgd_03, y_pgd_03)
plt.ylim(10**-7, 10**-3)
plt.yscale('log')

# %%
plt.scatter(x_pgd_05, y_pgd_05)
plt.ylim(10**-7, 10**-3)
plt.yscale('log')

# %%
plt.scatter(x_pgd_1, y_pgd_1)
plt.ylim(10**-7, 10**-3)
plt.yscale('log')

# %%
plt.scatter(x_pgd_4, y_pgd_4)
plt.ylim(10**-5, 10**-1)
plt.yscale('log')
