# %%
import os
import scipy
import numpy as np
import matplotlib.pyplot as plt
import obspy
import util
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# %%
root = '/home/earthquakes1/homes/Rebecca/phd/data/2019_global_m3/' #2018_2021_global_m5/'#'/home/earthquakes1/homes/Rebecca/phd/data/2019_global_m5/'
eq_list = os.listdir(root)

# %%
#client = Client("IRIS")
#cat = client.get_events(starttime=UTCDateTime("2019-06-26"), endtime=UTCDateTime("2020-06-26"), minlongitude=-179, maxlongitude=-145, minlatitude=42, maxlatitude=71, minmagnitude=5, includearrivals=True, includeallmagnitudes = True)
cat = obspy.read_events('/home/earthquakes1/homes/Rebecca/phd/data/2019_global_m3_catalog.xml') #2018_2021_global_m5_catalog.xml')

# %%
cat[0].magnitudes
# Out:
# [Magnitude
# 	    resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192468205")
# 	            mag: 4.5
# 	 magnitude_type: 'mb'
# 	  creation_info: CreationInfo(author='us')]

# %%
len(cat)
# Out:
# 15314

# %%
print('')

# %%
cat_with_data = cat.copy()
cat_with_data.clear()
for event in cat:
    eq_name = util.catEventToFileName(event)
    if os.path.isdir(root+eq_name) and os.path.isdir(root+eq_name+'/station_xml_files'):
        cat_with_data.extend([event])

# %%
mag_types = {}
for i in range(0, len(cat_with_data)):
    e = cat_with_data[i]
    if float(cat_with_data[i].magnitudes[0].mag):
        print('in if')
        key  = cat_with_data[i].magnitudes[0].magnitude_type[0:2]
        key = key.lower()
        print(key)
        if key[0:2]=='mw':
            key = 'mw'
    if key in mag_types.keys():
        mag_types[key] = np.append(mag_types[key], e.magnitudes[0].mag)
        print('in if')
    else:
        if e.magnitudes[0].mag != None:
            mag_types[key] = np.array([e.magnitudes[0].mag])  
            print('in else if')
        else:
            print('in else else')
# Out:
# in if
# mb
# in else if
# in if
# mw
# in else if
# in if
# ml
# in else if
# in if
# md
# in else if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# ...
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# ml
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# md
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# ml
# in if
# in if
# mb
# in if
# in if
# mw
# in if
# in if
# mb
# in if
# in if
# mb
# in if
# in if
# mb
# in if

# %%
mag_types
# Out:
# {'mb': array([ 4.3,  4.3,  4.3, ...,  4.3,  4.3,  4.3]),
#  'mw': array([ 4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3]),
#  'ml': array([ 4.3,  4.3,  4.3, ...,  4.3,  4.3,  4.3]),
#  'md': array([ 4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3]),
#  'mb_lg': array([ 4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3]),
#  'mlr': array([ 4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3,
#          4.3,  4.3,  4.3,  4.3,  4.3,  4.3,  4.3]),
#  'mh': array([ 4.3])}

# %%
i = 0
cat_with_data[i].magnitudes[0].mag
# Out:
# 4.2

# %%
len(cat_with_data)
# Out:
# 6077

# %%
types = {}
for e in cat_with_data:
    if len(e.magnitudes) >= 1:
        mt = []
        print(e)
        for m in e.magnitudes:
            mt.append(m.magnitude_type[:2].lower())
        if 'mb' in mt and ('mw' in mt or 'ml' in mt):
            key = 'both'
        elif 'mw' in mt:
            key = 'mw'
        elif 'mb' in mt:
            key = 'mb'
        else:
            key = 'other'
        if key in mag_types.keys():
            types[key] = np.append(mag_types[key], e.magnitudes[0].mag)
        else:
            if e.magnitudes[0].mag != None:
                types[key] = np.array([e.magnitudes[0].mag])
        #types[key] = types.get(key, 0) + 1
        #print(mt, '\n ===')
# Out:
# Event:	2019-01-31T19:49:49.660000Z | -20.486,  -69.016 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001567")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36907036")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192541937")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T13:09:53.370000Z |  +8.978,  -83.758 | 4.9 Mwr
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001444")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36901436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192340524")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T13:03:50.890000Z | +56.298, -149.259 | 4.1 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001445")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36901486")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192462685")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T10:16:56.840000Z | +17.957,  -68.394 | 3.09 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001433")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36900886")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192532634")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T08:55:20.080000Z | +53.523, -167.269 | 3.0 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11006102")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=37115089")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192517761")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T08:20:11.150000Z | +19.331,  -68.276 | 3.27 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001429")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36900686")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192502888")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T05:42:01.530000Z | -23.566,  -68.204 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11010246")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=37300186")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192569932")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T04:40:30.240000Z | +13.464,  -88.366 | 5.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001345")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36896736")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192344671")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T03:52:50.297000Z | +61.928, -149.821 | 3.7 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001332")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36896086")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192463079")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T03:17:14.820000Z | +19.168,  -68.219 | 3.28 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001400")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36899336")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192335955")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T03:13:36.090000Z | +35.365, -117.871 | 3.17 Ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001325")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36895736")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192376763")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-31T00:16:48.840000Z | +23.944, -109.061 | 5.3 Mww
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001256")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36893486")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192468311")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T23:12:59.480000Z | +23.979,  +94.500 | 4.0 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11006178")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=37117436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192463907")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T22:54:34.390000Z | +19.480,  -68.121 | 3.3 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001228")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36892186")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192332221")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T22:16:51.480000Z | +19.326,  -68.434 | 3.31 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001215")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36891686")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192332394")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T21:02:53.750000Z | +19.397,  -68.174 | 3.24 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001199")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36890936")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192332126")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T18:58:47.750000Z | +19.359,  -68.133 | 3.26 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001187")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36890286")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192540082")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T11:41:02.470000Z | +12.377,  -87.724 | 4.5 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001022")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36883136")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192568670")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T08:00:48.260000Z | +34.028, -117.230 | 3.2 Ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000970")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36880686")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192547241")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T07:44:45.250000Z | -25.898,  -70.668 | 5.6 Mww
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000968")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36880586")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192550426")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T07:22:09.640000Z | +55.680, -149.213 | 3.3 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000963")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36880386")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192501370")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T05:21:35.900000Z | +23.735, +122.495 | 5.3 Mww
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000950")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36879736")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192550263")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T05:04:35.500000Z | +19.291,  -68.068 | 3.9 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000947")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36879586")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192550211")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T02:40:12.280000Z | +34.408, -116.892 | 3.56 Ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000920")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36878286")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192448533")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T02:21:46.930000Z | +27.294, +129.042 | 4.5 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11005783")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=37102436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192448490")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-30T00:34:53.090000Z | +40.429, -125.504 | 3.4 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000904")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36877486")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192445908")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T22:52:52.000000Z | +12.863,  -88.281 | 4.5 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000877")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36876186")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192448669")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T21:49:22.470000Z | +18.998,  -68.815 | 3.2 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000863")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36875586")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192342785")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T21:29:04.475000Z | +57.947, -152.515 | 3.2 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000845")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36874836")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192463568")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T20:25:34.990000Z | -30.698,  -71.162 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000784")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36873086")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192469731")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T19:10:19.950000Z | +37.104,  +71.326 | 4.3 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000878")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36876236")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192469858")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T12:53:45.000000Z | +51.571,  +16.158 | 4.1 Mwr
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000662")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36867386")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192336386")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T11:59:04.184000Z | +61.411, -149.970 | 3.4 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000644")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36866536")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192463032")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-29T09:37:02.400000Z | -14.906, +167.341 | 4.9 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000623")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36865486")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192317024")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-28T16:46:06.110000Z | +19.219,  -67.725 | 3.18 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000418")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36857536")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192471906")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-28T06:46:18.700000Z | -32.574,  -71.848 | 3.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000415")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36857436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192536994")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-28T03:33:36.590000Z | -29.674,  -71.380 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000117")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36844636")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192306526")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-28T01:07:30.300000Z | +37.571,  +20.721 | 4.3 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000049")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36842886")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192304474")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T23:54:01.330000Z | -24.155,  -67.334 | 4.6 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000016")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36841286")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192304512")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T23:45:56.850000Z | +24.403,  +94.024 | 4.7 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000013")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36841136")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192304517")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T22:21:57.073000Z | +56.257, -149.173 | 3.0 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11003213")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36982687")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192382170")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T19:07:22.718000Z | +60.265, -153.115 | 3.0 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999957")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36838386")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192524783")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T18:24:04.540000Z | +19.425, -155.619 | 3.47 Ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999950")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36838036")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192524765")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T15:38:13.480000Z | +54.316, -161.540 | 3.0 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11003206")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36982537")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192439606")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T13:43:40.090000Z | +38.528,  +70.384 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999916")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36836436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192302504")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T12:32:44.480000Z | +53.185, -166.803 | 3.6 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11000031")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36841986")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192470741")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T11:10:49.270000Z | +34.272, -119.582 | 3.1 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999879")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36834586")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192470595")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T10:31:34.992000Z | +59.830, -153.003 | 3.4 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999874")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36834336")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192469105")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T04:49:20.490000Z | +24.805,  +94.303 | 4.7 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999824")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36831986")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192516815")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T04:16:42.050000Z | +56.173, -149.912 | 3.1 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11003171")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36981836")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192516745")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T03:15:42.800000Z | +39.022,  +27.839 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999819")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36831736")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192516665")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T01:21:08.990000Z | +39.474,  +20.512 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999801")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36830836")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192516607")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-27T01:03:14.610000Z | +32.875, -115.753 | 3.49 Ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999795")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36830536")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192516599")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-26T20:56:31.880000Z |  +6.585, +126.431 | 4.3 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11005239")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=37076436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192435969")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-26T07:48:54.120000Z | -30.054,  -71.536 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999660")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36823636")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192469219")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-26T00:31:30.360000Z | +36.401, +140.004 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999578")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36819636")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192300571")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T22:53:24.970000Z | +37.641,  +20.714 | 4.0 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11003788")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=37007636")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192401166")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T20:31:58.652000Z | +38.385, -115.829 | 3.8 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999533")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36817386")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192323337")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T20:20:35.160000Z | +38.632,  +27.082 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999551")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36818286")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192516672")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T18:32:40.800000Z | +37.059,  -97.366 | 3.4 mb_Lg
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999507")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36816136")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192460128")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T17:07:08.510000Z | +24.310,  +93.892 | 4.6 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999489")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36815336")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192444885")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T15:49:34.430000Z | -33.506,  -70.267 | 4.3 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999618")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36821586")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192298329")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T13:34:14.042000Z | +57.025, -155.647 | 3.3 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999444")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36813136")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192346250")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T12:58:40.172000Z | +52.452, -171.224 | 3.1 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11001862")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36920036")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192346333")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T09:52:12.190000Z | +17.870,  -68.178 | 3.07 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999430")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36812436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192294890")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T09:31:00.930000Z | -20.208,  -68.814 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999411")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36811486")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192294712")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T08:47:11.550000Z | +18.720,  -65.208 | 3.18 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999427")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36812286")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192468987")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T08:29:17.680000Z | -30.180,  -71.506 | 4.5 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999395")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36810686")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192468935")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T07:47:03.110000Z | +42.563, +141.578 | 4.1 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999390")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36810436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192468915")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T06:56:21.540000Z | -22.104,  -68.813 | 4.0 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999384")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36810136")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192294406")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T06:27:43.411000Z | +61.490, -150.225 | 3.1 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999374")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36809636")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192468901")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-25T03:49:00.397000Z | +57.340, -154.597 | 3.5 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999338")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36807886")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192515599")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T20:12:54.316000Z | +59.754, -153.148 | 3.5 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999061")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36798436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192471976")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T16:38:05.020000Z | +35.862,  -96.687 | 3.5 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999022")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36796536")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192440306")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T16:20:01.930000Z | +12.974,  -89.087 | 4.6 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999021")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36796486")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192440096")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T14:30:49.870000Z | +36.016,  +28.177 | 5.3 Mww
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10998981")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36794536")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192297049")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T14:12:19.150000Z | -40.497, +173.406 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999031")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36796986")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192287888")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T13:13:30.882000Z | +61.508, -149.901 | 3.0 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10998967")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36793736")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192470841")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T12:30:34.472000Z | +61.379, -147.213 | 3.6 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10998961")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36793436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192333936")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T12:15:17.950000Z | +26.952, +128.121 | 4.7 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10998962")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36793486")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192297652")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T11:20:24.002000Z | +53.870, -161.953 | 3.2 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999140")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36800586")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192333810")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T10:28:29.320000Z | -30.106,  -71.278 | 5.1 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10998943")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36792536")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=192306783")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-01-24T08:06:10.060000Z | -35.006,  -71.918 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=10999170")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=36801686")
# ...
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090553")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40841936")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195389542")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T10:56:18.969000Z | +36.362,  -98.153 | 3.41 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090534")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40840986")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195323320")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T06:50:51.354000Z | -34.142,  -72.245 | 4.6 Mwr
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090473")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40838186")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195459628")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T06:41:42.594000Z | -34.190,  -72.272 | 4.6 Mwr
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090467")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40837887")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195459610")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T06:31:37.417000Z |  -4.945, +151.278 | 4.4 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11102697")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=41071690")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195459559")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T05:38:18.140000Z | +19.567,  -67.838 | 3.1 Md
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090493")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40839136")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195459410")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T02:19:18.197000Z | -15.394, +167.644 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11094795")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40981296")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195591813")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T01:25:00.420000Z | +59.742, -153.291 | 3.4 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090374")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40833436")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195591658")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T00:55:16.872000Z | -34.179,  -72.198 | 5.4 Mww
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090368")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40833137")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195236123")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T00:14:34.500000Z |  -3.668, +152.157 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11096537")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=41000490")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195308571")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T00:09:15.018000Z | -34.154,  -72.285 | 4.2 Mwr
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090343")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40832036")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195156923")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-02T00:07:43.705000Z |  +6.890,  -73.048 | 4.3 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11095986")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40994794")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195293604")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T23:24:19.564000Z | +55.988, -149.592 | 3.4 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090322")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40831186")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195495001")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T22:06:51.407000Z | -15.659, -177.466 | 4.1 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11095977")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40994737")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195293442")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T21:48:59.717000Z | +57.920, -137.745 | 3.1 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090273")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40828836")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195522888")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T21:11:37.470000Z | +36.194, -117.891 | 3.2 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090255")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40827936")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195254195")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T20:01:28.357000Z | -34.272,  -72.379 | 5.6 Mww
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090230")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40826886")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195434737")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T19:36:25.649000Z | -34.188,  -72.191 | 4.9 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090235")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40827086")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195415160")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T18:28:07.272000Z | -34.237,  -72.308 | 6.8 mww
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090197")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40825336")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195415141")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T18:12:10.979000Z |  +6.773,  -72.954 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090216")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40826286")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195414966")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T16:17:11.606000Z | +55.785, -149.189 | 3.0 ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11103746")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=41081187")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195494928")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T15:37:27.690000Z | +17.869,  -66.306 | 3.1 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090118")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40821786")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195159806")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T12:06:43.316000Z | +58.436, -153.637 | 3.0 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090043")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40818286")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195494811")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T10:31:24.740000Z | +35.956, -117.713 | 3.17 Ml
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11090019")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=40817086")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195232580")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T08:50:31.055000Z | +23.632, +118.746 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11102565")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=41069988")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195457395")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T08:40:42.858000Z | +56.898, -146.944 | 3.1 ML
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11102563")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=41069986")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195494835")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# Event:	2019-08-01T08:39:23.414000Z | +25.849, +128.512 | 4.2 mb
#
# 	            resource_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?eventid=11102562")
# 	             event_type: 'earthquake'
# 	    preferred_origin_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?originid=41069940")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:service.iris.edu/fdsnws/event/1/query?magnitudeid=195457320")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
types
# Out:
# {'mb': array([ 4.3,  4.3]),
#  'mw': array([ 4.7,  4.7]),
#  'other': array([ 3.2,  3.2])}

# %%
len(types['both'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_697233/2301918968.py in <module>
# ----> 1 len(types['both'])
#
# KeyError: 'both'

# %%
mag_types = {}
for i in range(0, len(cat_with_data)):
    if float(cat_with_data[i].magnitudes[0].mag):
        key  = cat_with_data[i].magnitudes[0].magnitude_type
        key = key.lower()
        if key[0:2]=='mw':
            key = 'mw_all'
        if key in mag_types.keys():
            mag_types[key] = np.append(mag_types[key], cat_with_data[i].magnitudes[0].mag)
        else:
            if cat_with_data[i].magnitudes[0].mag != None:
                mag_types[key] = np.array([cat_with_data[i].magnitudes[0].mag])

# %%
mag_types
# Out:
# {}

# %%
# %matplotlib qt
#mag_types = types.copy()
count = 0
hatches = ['/', '\\', '-', '+', 'x', 'o', 'O', '.', '*']
colors = ['#0f85a0','#edd746','#ed8b00','#dd4124']

colors = ['#0f85a0','#dd4124', '#ed8b00', '#edd746', '#808080', '#ed8b00',  '#00496f']
for key in mag_types.keys():
    #plt.scatter(np.zeros(len(mag_types[key]))+count, mag_types[key])
    print(key, str(len(mag_types[key])))
    if len(mag_types[key])>0:
        plt.hist(mag_types[key], np.arange(3, 8, 0.1), color = colors[count], histtype = 'step', hatch = hatches[count], label = key+str(len(mag_types[key])))
        plt.hist(mag_types[key], np.arange(3, 8, 0.1), color = colors[count], histtype = 'bar', alpha = 0.15)
        count += 1
plt.ylabel('n')
plt.xlabel('event magnitude')
plt.title('magnitude distribution by magnitude type')
plt.legend()
# Out:
# mb 2469
# mw 772
# ml 2248
# md 587
# mh 1

# %%
cat2 = cat_with_data.filter("magnitude >= 6.6")

# %%
cat2

# %%
cat2[0]
